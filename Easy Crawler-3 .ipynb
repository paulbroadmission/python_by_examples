# %% [markdown]
# # Python Examples: Easy Crawler 3 by Paul Chao #

# %%
import requests

# %%
resp = requests.get("https://udn.com/news/index")
resp
# Out:
# <Response [200]>

# %%
resp.text
# Out:
# '<!--content 0.2082 --><!--ad_1 0.0653 --><!-- v441 --><!--ad 0.3261 --><!--view_type 0.0000 --><!--meta 0.0002 --><!--family_bar 0.0006 --><!--family_bar sub  --><!--breaking_news 0.0004 --><!--top 0.0029 --><!--bottom 0.0022 --><!--nav 0.0000 --><!--code 0.5410 --><!DOCTYPE HTML PUBLIC "-//W3C//DTD HTML 4.01 Transitional//EN" "http://www.w3.org/TR/html4/loose.dtd"><html><head><meta http-equiv="X-UA-Compatible" content="IE=edge,chrome=1"><meta http-equiv="Content-Type" content="text/html; charset=utf-8"><meta http-equiv="content-language" content="zh-Hant-TW"><meta name="viewport" content="width=device-width, initial-scale=1.0, maximum-scale=2.0" /><!-- favicon --><link rel="icon" type="image/x-icon" href="/static/img/favicon.ico" /><meta name="twitter:card" content="summary" /><!-- for Facebook --><meta property="og:title" content="聯合新聞網：觸動未來 新識力"/><meta property="og:type" content="article"/><meta property="og:url" content="https://udn.com/news/index"/><meta property="og:image" con
# ...

# %%
resp.encoding
# Out:
# 'UTF-8'

# %%
resp.encoding = 'utf-8'

# %%
resp.text
# Out:
# '<!--content 0.2082 --><!--ad_1 0.0653 --><!-- v441 --><!--ad 0.3261 --><!--view_type 0.0000 --><!--meta 0.0002 --><!--family_bar 0.0006 --><!--family_bar sub  --><!--breaking_news 0.0004 --><!--top 0.0029 --><!--bottom 0.0022 --><!--nav 0.0000 --><!--code 0.5410 --><!DOCTYPE HTML PUBLIC "-//W3C//DTD HTML 4.01 Transitional//EN" "http://www.w3.org/TR/html4/loose.dtd"><html><head><meta http-equiv="X-UA-Compatible" content="IE=edge,chrome=1"><meta http-equiv="Content-Type" content="text/html; charset=utf-8"><meta http-equiv="content-language" content="zh-Hant-TW"><meta name="viewport" content="width=device-width, initial-scale=1.0, maximum-scale=2.0" /><!-- favicon --><link rel="icon" type="image/x-icon" href="/static/img/favicon.ico" /><meta name="twitter:card" content="summary" /><!-- for Facebook --><meta property="og:title" content="聯合新聞網：觸動未來 新識力"/><meta property="og:type" content="article"/><meta property="og:url" content="https://udn.com/news/index"/><meta property="og:image" con
# ...

# %%
from bs4 import BeautifulSoup

soup = BeautifulSoup(resp.text, "html.parser")

# %%
table = soup.select("#tab1")

# %%
table
# Out:
# [<div id="tab1"> <dl> <dt><a class="taba " href="https://udn.com/news/story/7326/2978167"><b>15:14</b>台南市府春聯有賴清德聯名！市民直呼：賺到啦！</a></dt> <dt><a class="taba sp" href="https://udn.com/news/story/7241/2978163"><b>15:12</b>中油大林廠突檢9缺失 高市環保局要戴謙上環教課程</a></dt> <dt><a class="taba " href="https://udn.com/news/story/7328/2978161"><b>15:10</b>遠東集團捐3千萬賑災 民：花蓮舊遠百何時拆？</a></dt> <dt><a class="taba " href="https://udn.com/news/story/7270/2978160"><b>15:10</b>迎春特惠 床墊祭優惠享好禮 寢具花團錦簇開好運</a></dt> <dt><a class="taba sp" href="https://udn.com/news/story/6813/2978158"><b>15:09</b>美國政府短暫關閉後再開門 眾院接手趕通過預算案</a></dt> <dt><a class="taba sp" href="https://udn.com/news/story/6809/2978157"><b>15:09</b>【重磅快評】金正恩的妹妹是他最後一張王牌</a></dt> <dt><a class="taba " href="https://udn.com/news/story/7314/2978139"><b>15:01</b>聞震色變！地調所電話被打爆 查詢活動斷層網站也塞爆</a></dt> <dt><a class="taba " href="https://udn.com/news/story/7314/2978132"><b>14:58</b>德翔與漁民賠償金談不攏 今協商破局法院見</a></dt> <dt><a class="taba " href="https://udn.com/news/story/6904/2978129"><b>
# ...

# %%
table[0].text
# Out:
# '  15:14台南市府春聯有賴清德聯名！市民直呼：賺到啦！ 15:12中油大林廠突檢9缺失 高市環保局要戴謙上環教課程 15:10遠東集團捐3千萬賑災 民：花蓮舊遠百何時拆？ 15:10迎春特惠 床墊祭優惠享好禮 寢具花團錦簇開好運 15:09美國政府短暫關閉後再開門 眾院接手趕通過預算案 15:09【重磅快評】金正恩的妹妹是他最後一張王牌 15:01聞震色變！地調所電話被打爆 查詢活動斷層網站也塞爆 14:58德翔與漁民賠償金談不攏 今協商破局法院見 14:56男理工、女人文？ 科教館與北市大開發桌遊打破迷思  '

# %% [markdown]
# ## 分項取得 ##

# %%
scope = soup.select("#tab1")

# %%
scope
# Out:
# [<div id="tab1"> <dl> <dt><a class="taba " href="https://udn.com/news/story/7326/2978167"><b>15:14</b>台南市府春聯有賴清德聯名！市民直呼：賺到啦！</a></dt> <dt><a class="taba sp" href="https://udn.com/news/story/7241/2978163"><b>15:12</b>中油大林廠突檢9缺失 高市環保局要戴謙上環教課程</a></dt> <dt><a class="taba " href="https://udn.com/news/story/7328/2978161"><b>15:10</b>遠東集團捐3千萬賑災 民：花蓮舊遠百何時拆？</a></dt> <dt><a class="taba " href="https://udn.com/news/story/7270/2978160"><b>15:10</b>迎春特惠 床墊祭優惠享好禮 寢具花團錦簇開好運</a></dt> <dt><a class="taba sp" href="https://udn.com/news/story/6813/2978158"><b>15:09</b>美國政府短暫關閉後再開門 眾院接手趕通過預算案</a></dt> <dt><a class="taba sp" href="https://udn.com/news/story/6809/2978157"><b>15:09</b>【重磅快評】金正恩的妹妹是他最後一張王牌</a></dt> <dt><a class="taba " href="https://udn.com/news/story/7314/2978139"><b>15:01</b>聞震色變！地調所電話被打爆 查詢活動斷層網站也塞爆</a></dt> <dt><a class="taba " href="https://udn.com/news/story/7314/2978132"><b>14:58</b>德翔與漁民賠償金談不攏 今協商破局法院見</a></dt> <dt><a class="taba " href="https://udn.com/news/story/6904/2978129"><b>
# ...

# %%
scope2 = scope[0].select(".taba")

# %%
scope2
# Out:
# [<a class="taba " href="https://udn.com/news/story/7326/2978167"><b>15:14</b>台南市府春聯有賴清德聯名！市民直呼：賺到啦！</a>,
#  <a class="taba sp" href="https://udn.com/news/story/7241/2978163"><b>15:12</b>中油大林廠突檢9缺失 高市環保局要戴謙上環教課程</a>,
#  <a class="taba " href="https://udn.com/news/story/7328/2978161"><b>15:10</b>遠東集團捐3千萬賑災 民：花蓮舊遠百何時拆？</a>,
#  <a class="taba " href="https://udn.com/news/story/7270/2978160"><b>15:10</b>迎春特惠 床墊祭優惠享好禮 寢具花團錦簇開好運</a>,
#  <a class="taba sp" href="https://udn.com/news/story/6813/2978158"><b>15:09</b>美國政府短暫關閉後再開門 眾院接手趕通過預算案</a>,
#  <a class="taba sp" href="https://udn.com/news/story/6809/2978157"><b>15:09</b>【重磅快評】金正恩的妹妹是他最後一張王牌</a>,
#  <a class="taba " href="https://udn.com/news/story/7314/2978139"><b>15:01</b>聞震色變！地調所電話被打爆 查詢活動斷層網站也塞爆</a>,
#  <a class="taba " href="https://udn.com/news/story/7314/2978132"><b>14:58</b>德翔與漁民賠償金談不攏 今協商破局法院見</a>,
#  <a class="taba " href="https://udn.com/news/story/6904/2978129"><b>14:56</b>男理工、女人文？ 科教館與北市大開發桌遊打破迷思</a>]

# %%
scope2[0].text
# Out:
# '15:14台南市府春聯有賴清德聯名！市民直呼：賺到啦！'

# %%
for line in scope2:
    print(line.text)
# Out:
# 15:14台南市府春聯有賴清德聯名！市民直呼：賺到啦！
# 15:12中油大林廠突檢9缺失 高市環保局要戴謙上環教課程
# 15:10遠東集團捐3千萬賑災 民：花蓮舊遠百何時拆？
# 15:10迎春特惠 床墊祭優惠享好禮 寢具花團錦簇開好運
# 15:09美國政府短暫關閉後再開門 眾院接手趕通過預算案
# 15:09【重磅快評】金正恩的妹妹是他最後一張王牌
# 15:01聞震色變！地調所電話被打爆 查詢活動斷層網站也塞爆
# 14:58德翔與漁民賠償金談不攏 今協商破局法院見
# 14:56男理工、女人文？ 科教館與北市大開發桌遊打破迷思

# %% [markdown]
# ## 更細切項 ##

# %%
scope3 = scope2[0].select("b")

# %%
scope3
# Out:
# [<b>15:14</b>]

# %%
scope3[0].text
# Out:
# '15:14'

# %%
line = scope2[0].text
print(line)
# Out:
# 15:14台南市府春聯有賴清德聯名！市民直呼：賺到啦！

# %%
print(line[5:])
# Out:
# 台南市府春聯有賴清德聯名！市民直呼：賺到啦！

# %% [markdown]
# ## sample code 你的第一支新聞爬蟲 ##

# %%
import requests
from bs4 import BeautifulSoup

def get_hotline_udnnews(url):
    resp = requests.get(url)
    
    if resp.status_code is 200:
        resp.encoding = 'utf-8'
        soup = BeautifulSoup(resp.text, 'html.parser')
        scope1 = soup.select("#tab1") #選取第一區段
        scope2 = scope1[0].select(".taba") #選取第二區段
        
        hot_lines = []
        
        for line in scope2: #集成於一個list，後可回傳
            hot_lines.append(line.text) 
            
        return hot_lines


if __name__ == '__main__':
    udnnews_lines = get_hotline_udnnews("https://udn.com/news/index")
    i = 0
    
    while i < len(udnnews_lines): 
        print(udnnews_lines[i])
        i += 1
# Out:
# 15:14台南市府春聯有賴清德聯名！市民直呼：賺到啦！
# 15:12中油大林廠突檢9缺失 高市環保局要戴謙上環教課程
# 15:10遠東集團捐3千萬賑災 民：花蓮舊遠百何時拆？
# 15:10迎春特惠 床墊祭優惠享好禮 寢具花團錦簇開好運
# 15:09美國政府短暫關閉後再開門 眾院接手趕通過預算案
# 15:09【重磅快評】金正恩的妹妹是他最後一張王牌
# 15:01聞震色變！地調所電話被打爆 查詢活動斷層網站也塞爆
# 14:58德翔與漁民賠償金談不攏 今協商破局法院見
# 14:56男理工、女人文？ 科教館與北市大開發桌遊打破迷思

# %% [markdown]
# ## 分解資料方便儲存 ##
# 把時間與內容分離儲存

# %%
import requests
from bs4 import BeautifulSoup

def get_hotline_udnnews(url):
    resp = requests.get(url)
    
    if resp.status_code is 200:
        resp.encoding = 'utf-8'
        soup = BeautifulSoup(resp.text, 'html.parser')
        scope1 = soup.select("#tab1") #選取第一區段
        scope2 = scope1[0].select(".taba") #選取第二區段
        
        hot_lines = []
        
        for line in scope2: #集成於一個list，後可回傳
            hot_lines.append(line.text)
            
        return hot_lines


if __name__ == '__main__':
    udnnews_lines = get_hotline_udnnews("https://udn.com/news/index")
    i = 0
    udnnews_dicts = {}
    while i < len(udnnews_lines):  #運用 dictionary達成分項的效果
        udnnews_dicts['time'] = udnnews_lines[i][:5]
        udnnews_dicts['title'] = udnnews_lines[i][5:]
        print("Time[{}]: {}".format(udnnews_dicts['time'], udnnews_dicts['title']))
        i += 1
# Out:
# Time[15:14]: 台南市府春聯有賴清德聯名！市民直呼：賺到啦！
# Time[15:12]: 中油大林廠突檢9缺失 高市環保局要戴謙上環教課程
# Time[15:10]: 遠東集團捐3千萬賑災 民：花蓮舊遠百何時拆？
# Time[15:10]: 迎春特惠 床墊祭優惠享好禮 寢具花團錦簇開好運
# Time[15:09]: 美國政府短暫關閉後再開門 眾院接手趕通過預算案
# Time[15:09]: 【重磅快評】金正恩的妹妹是他最後一張王牌
# Time[15:01]: 聞震色變！地調所電話被打爆 查詢活動斷層網站也塞爆
# Time[14:58]: 德翔與漁民賠償金談不攏 今協商破局法院見
# Time[14:56]: 男理工、女人文？ 科教館與北市大開發桌遊打破迷思

# %% [markdown]
# ## 運用 Pandas 與資料庫套件整理成新聞資料庫 ##

# %%
udnnews_lines = get_hotline_udnnews("https://udn.com/news/index")
udnnews_lines
# Out:
# ['15:14台南市府春聯有賴清德聯名！市民直呼：賺到啦！',
#  '15:12中油大林廠突檢9缺失 高市環保局要戴謙上環教課程',
#  '15:10遠東集團捐3千萬賑災 民：花蓮舊遠百何時拆？',
#  '15:10迎春特惠 床墊祭優惠享好禮 寢具花團錦簇開好運',
#  '15:09美國政府短暫關閉後再開門 眾院接手趕通過預算案',
#  '15:09【重磅快評】金正恩的妹妹是他最後一張王牌',
#  '15:01聞震色變！地調所電話被打爆 查詢活動斷層網站也塞爆',
#  '14:58德翔與漁民賠償金談不攏 今協商破局法院見',
#  '14:56男理工、女人文？ 科教館與北市大開發桌遊打破迷思']

# %%
udnnews_new_lines = {}
i=0
while i < len(udnnews_lines):
    udnnews_new_lines[udnnews_lines[i][:5]] = udnnews_lines[i][5:]
    i += 1

udnnews_new_lines
# Out:
# {'14:56': '男理工、女人文？ 科教館與北市大開發桌遊打破迷思',
#  '14:58': '德翔與漁民賠償金談不攏 今協商破局法院見',
#  '15:01': '聞震色變！地調所電話被打爆 查詢活動斷層網站也塞爆',
#  '15:09': '【重磅快評】金正恩的妹妹是他最後一張王牌',
#  '15:10': '迎春特惠 床墊祭優惠享好禮 寢具花團錦簇開好運',
#  '15:12': '中油大林廠突檢9缺失 高市環保局要戴謙上環教課程',
#  '15:14': '台南市府春聯有賴清德聯名！市民直呼：賺到啦！'}

# %% [markdown]
# ### 打上年月日 ###

# %%
import time
print(time.strftime("%Y%m%d"))
# Out:
# 20180209

# %%
udnnews_new_lines = {}
i=0
while i < len(udnnews_lines):
    udnnews_new_lines[time.strftime("%Y%m%d")+"-"+udnnews_lines[i][:5]] = udnnews_lines[i][5:]
    i += 1

udnnews_new_lines
# Out:
# {'20180209-14:56': '男理工、女人文？ 科教館與北市大開發桌遊打破迷思',
#  '20180209-14:58': '德翔與漁民賠償金談不攏 今協商破局法院見',
#  '20180209-15:01': '聞震色變！地調所電話被打爆 查詢活動斷層網站也塞爆',
#  '20180209-15:09': '【重磅快評】金正恩的妹妹是他最後一張王牌',
#  '20180209-15:10': '迎春特惠 床墊祭優惠享好禮 寢具花團錦簇開好運',
#  '20180209-15:12': '中油大林廠突檢9缺失 高市環保局要戴謙上環教課程',
#  '20180209-15:14': '台南市府春聯有賴清德聯名！市民直呼：賺到啦！'}

# %% [markdown]
# ### 用 Pandas 整理資料 ###

# %%
import pandas as pd
df = pd.DataFrame([udnnews_new_lines])
#df.from_dict(udnnews_new_lines,orient='index')
df
# Out:
#              20180209-14:56        20180209-14:58             20180209-15:01  \
# 0  男理工、女人文？ 科教館與北市大開發桌遊打破迷思  德翔與漁民賠償金談不攏 今協商破局法院見  聞震色變！地調所電話被打爆 查詢活動斷層網站也塞爆
#
#          20180209-15:09           20180209-15:10            20180209-15:12  \
# 0  【重磅快評】金正恩的妹妹是他最後一張王牌  迎春特惠 床墊祭優惠享好禮 寢具花團錦簇開好運  中油大林廠突檢9缺失 高市環保局要戴謙上環教課程
#
#            20180209-15:14
# 0  台南市府春聯有賴清德聯名！市民直呼：賺到啦！

# %%
df = pd.DataFrame([udnnews_new_lines],index=['Title']).T
df
# Out:
#                                     Title
# 20180209-14:56   男理工、女人文？ 科教館與北市大開發桌遊打破迷思
# 20180209-14:58       德翔與漁民賠償金談不攏 今協商破局法院見
# 20180209-15:01  聞震色變！地調所電話被打爆 查詢活動斷層網站也塞爆
# 20180209-15:09       【重磅快評】金正恩的妹妹是他最後一張王牌
# 20180209-15:10    迎春特惠 床墊祭優惠享好禮 寢具花團錦簇開好運
# 20180209-15:12   中油大林廠突檢9缺失 高市環保局要戴謙上環教課程
# 20180209-15:14     台南市府春聯有賴清德聯名！市民直呼：賺到啦！

# %% [markdown]
# ### 使用封裝好的 database 函式來存入資料 ###

# %%
item = df.iloc[0]
item
# Out:
# Title    男理工、女人文？ 科教館與北市大開發桌遊打破迷思
# Name: 20180209-14:56, dtype: object

# %%
item['Title']
# Out:
# '男理工、女人文？ 科教館與北市大開發桌遊打破迷思'

# %%
item.name
# Out:
# '20180209-14:56'

# %%
len(df.index)
# Out:
# 7

# %% [markdown]
# ### 含入 database 的函式代碼 ###

# %% [markdown]
# ``` Python
# import leveldb
#
# # converting functions
# def cvt_to_bytes(string):
#     # leave type check for system exceptions
#     return string.encode()
#
#
# def cvt_to_string(bytestring):
#     # leave type check for system exceptions
#     return bytestring.decode('utf-8')
#
#
# def cvt_b(key, value):
#     key_b = key
#     value_b = value
#     if isinstance(key, str):
#         key_b = cvt_to_bytes(key)
#     if isinstance(value, str):
#         value_b = cvt_to_bytes(value)
#     return key_b, value_b
#
#
# def cvt_s(key, value):
#     key_s = key
#     value_s = value
#
#     if isinstance(key, (bytes, bytearray)):
#         key_s = cvt_to_string(key)
#     if isinstance(value, (bytes, bytearray)):
#         value_s = cvt_to_string(value)
#     return key_s, value_s
#
#
# # database functions
# def init(filename):
#     db = leveldb.LevelDB(filename)
#     return db
#
#
# def insert(db, key, value):
#     key_b, name_b = cvt_b(key, value)
#     db.Put(key_b, name_b)
#
#
# def delete(db, key):
#     key_b = cvt_to_bytes(key)
#     db.Delete(key_b)
#
#
# def update(db, key, value):
#     key_b, name_b = cvt_b(key, value)
#     db.Put(key_b, name_b)
#
#
# def search(db, key):
#     key_b = cvt_to_bytes(key)
#     value = db.Get(key_b)
#     value_str = cvt_to_string(value)
#     return value_str
#
#
# def dump(db):
#     # add container
#     item_list = []
#     for key, value in db.RangeIter():
#         key_s, value_s = cvt_s(key, value)
#         item_list.append((key_s, value))
#         print (key_s, value_s)
#     return item_list
# ```

# %% [markdown]
# ### 存入新聞資料庫 ###

# %% [markdown]
# ``` Python
# import time
# import pandas as pd
#
# # 整理資料
# udnnews_new_lines = {}
# i=0
# while i < len(udnnews_lines):
#     udnnews_new_lines[time.strftime("%Y%m%d")+"-"+udnnews_lines[i][:5]] = udnnews_lines[i][5:]
#     i += 1
#
# df = pd.DataFrame([udnnews_new_lines],index=['Title']).T
#
# # 寫入資料庫
# db = init('news.db'):
# i=0
# while i < len(df.index):
#     item = df.iloc[i]
#     insert(db, item.name, item['Title'])
#     i = i + 1
#
# # 列出資料庫
# print("新聞資料庫內容:\n")
# dump(db)
# ```

# %% [markdown]
# ## 即時新聞爬蟲資料庫程式集成 ##

# %% [markdown]
# ``` Python
# import time
# import requests
# from bs4 import BeautifulSoup
# import pandas as pd
# import leveldb
#
# # converting functions
# def cvt_to_bytes(string):
#     # leave type check for system exceptions
#     return string.encode()
#
#
# def cvt_to_string(bytestring):
#     # leave type check for system exceptions
#     return bytestring.decode('utf-8')
#
#
# def cvt_b(key, value):
#     key_b = key
#     value_b = value
#     if isinstance(key, str):
#         key_b = cvt_to_bytes(key)
#     if isinstance(value, str):
#         value_b = cvt_to_bytes(value)
#     return key_b, value_b
#
#
# def cvt_s(key, value):
#     key_s = key
#     value_s = value
#
#     if isinstance(key, (bytes, bytearray)):
#         key_s = cvt_to_string(key)
#     if isinstance(value, (bytes, bytearray)):
#         value_s = cvt_to_string(value)
#     return key_s, value_s
#
#
# # database functions
# def init(filename):
#     db = leveldb.LevelDB(filename)
#     return db
#
#
# def insert(db, key, value):
#     key_b, name_b = cvt_b(key, value)
#     db.Put(key_b, name_b)
#
#
# def delete(db, key):
#     key_b = cvt_to_bytes(key)
#     db.Delete(key_b)
#
#
# def update(db, key, value):
#     key_b, name_b = cvt_b(key, value)
#     db.Put(key_b, name_b)
#
#
# def search(db, key):
#     key_b = cvt_to_bytes(key)
#     value = db.Get(key_b)
#     value_str = cvt_to_string(value)
#     return value_str
#
#
# def dump(db):
#     # add container
#     item_list = []
#     for key, value in db.RangeIter():
#         key_s, value_s = cvt_s(key, value)
#         item_list.append((key_s, value))
#         print (key_s, value_s)
#     return item_list
#
# # 爬蟲
# def get_hotline_udnnews(url):
#     resp = requests.get(url)
#
#     if resp.status_code is 200:
#         resp.encoding = 'utf-8'
#         soup = BeautifulSoup(resp.text, 'html.parser')
#         scope1 = soup.select("#tab1") #選取第一區段
#         scope2 = scope1[0].select(".taba") #選取第二區段
#
#         hot_lines = []
#
#         for line in scope2: #集成於一個list，後可回傳
#             hot_lines.append(line.text)
#
#         return hot_lines
#
#
# if __name__ == '__main__':
#     udnnews_lines = get_hotline_udnnews("https://udn.com/news/index")
#
#     # 整理資料
#     udnnews_new_lines = {}
#     i=0
#     while i < len(udnnews_lines):
#         udnnews_new_lines[time.strftime("%Y%m%d")+"-"+udnnews_lines[i][:5]] = udnnews_lines[i][5:]
#         i += 1
#
#     df = pd.DataFrame([udnnews_new_lines],index=['Title']).T
#
#     # 寫入資料庫
#     db = init('news.db')
#     i=0
#     while i < len(df.index):
#         print("item = ", df.iloc[i])
#         item = df.iloc[i]
#         insert(db, str(item.name), str(item['Title']))
#         i = i + 1
#
#     # 列出資料庫
#     print("新聞資料庫內容:\n")
#     dump(db)
# ```

# %% [markdown]
# ## 加入網頁瀏覽 ##

# %% [markdown]
# ``` Python
# from flask import Flask, render_template, send_from_directory
# from gtts import gTTS
# import leveldb
#
#
# # converting functions
# def cvt_to_bytes(string):
#     # leave type check for system exceptions
#     return string.encode()
#
#
# def cvt_to_string(bytestring):
#     # leave type check for system exceptions
#     return bytestring.decode()
#
#
# def cvt_b(key, value):
#     key_b = key
#     value_b = value
#     if isinstance(key, str):
#         key_b = cvt_to_bytes(key)
#     if isinstance(value, str):
#         value_b = cvt_to_bytes(value)
#     return key_b, value_b
#
#
# def cvt_s(key, value):
#     key_s = key
#     value_s = value
#
#     if isinstance(key, (bytes, bytearray)):
#         key_s = cvt_to_string(key)
#     if isinstance(value, (bytes, bytearray)):
#         value_s = cvt_to_string(value)
#     return key_s, value_s
#
#
# # database functions
# def init(filename):
#     db = leveldb.LevelDB(filename)
#     return db
#
#
# def insert(db, key, value):
#     key_b, name_b = cvt_b(key, value)
#     db.Put(key_b, name_b)
#
#
# def delete(db, key):
#     key_b = cvt_to_bytes(key)
#     db.Delete(key_b)
#
#
# def update(db, key, value):
#     key_b, name_b = cvt_b(key, value)
#     db.Put(key_b, name_b)
#
#
# def search(db, key):
#     key_b = cvt_to_bytes(key)
#     value = db.Get(key_b)
#     value_str = cvt_to_string(value)
#     return value_str
#
#
# def dump(db):
#     # add container
#     item_list = []
#     for key, value in db.RangeIter():
#         key_s, value_s = cvt_s(key, value)
#         item_list.append((key_s, value_s))
#         print (key_s, value_s)
#         #print (type(key_s), type(value_s))
#     return item_list
#
#
# app = Flask(__name__)
#
# @app.route('/')
# def root():
#     db = init('news.db')
#     news_list = dump(db)
#     #print("now:\n", news_list)
#     return render_template("index.html", news=[news_list])
#
# @app.route('/voice=<string:news_text>')
# def paul(news_text):
#     tts=gTTS(text=news_text, lang='zh')
#     tts.save("broadmission_madnews.mp3")
#     return send_from_directory(directory='.', filename='broadmission_madnews.mp3')
#
#
# if __name__ == '__main__':
#     app.run(host="0.0.0.0", debug=True)
# ```
